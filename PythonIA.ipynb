# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexCaturyty/IA_Pyhton/blob/main/PythonIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto Python IA: Inteligência Artificial e Previsões
#
# ### Case: Score de Crédito dos Clientes
#
# Você foi contratado por um banco para conseguir definir o score de crédito dos clientes. Você precisa analisar todos os clientes do banco e, com base nessa análise, criar um modelo que consiga ler as informações do cliente e dizer automaticamente o score de crédito dele: Ruim, Ok, Bom
#
# Arquivos da aula: https://drive.google.com/drive/folders/1FbDqVq4XLvU85VBlVIMJ73p9oOu6u2-J?usp=drive_link

# %%
#Entender o desafio da empresa
#importar a base de dados
#preparar a base de dados para a inteligencia artifical
#criar um modelo de ia -> score de crédito: bom, médio ou ruim
#escolhar melhor modelo
#usar a IA para fazer previsões

# !pip install pandas numpy scikit-learn

# %%
import pandas as pd

tabela = pd.read_csv("clientes.csv")
display(tabela)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-a328fca38e5e> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 tabela = pd.read_csv("clientes.csv")
#       4 display(tabela)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
display(tabela.info())

# %%
# Para trabalhar para IA temos que tranformar tudo que vamos utilizar em números
# com isso vamos transformar os que estão object (profissão, mix_credito e comporatmento_pagamento) em inteiro

from sklearn.preprocessing import LabelEncoder

codificador = LabelEncoder()

tabela["profissao"] = codificador.fit_transform(tabela["profissao"])
tabela["mix_credito"] = codificador.fit_transform(tabela["mix_credito"])
tabela["comportamento_pagamento"] = codificador.fit_transform(tabela["comportamento_pagamento"])

print(tabela.info())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f6069f0f35bd> in <cell line: 8>()
#       6 codificador = LabelEncoder()
#       7
# ----> 8 tabela["profissao"] = codificador.fit_transform(tabela["profissao"])
#       9 tabela["mix_credito"] = codificador.fit_transform(tabela["mix_credito"])
#      10 tabela["comportamento_pagamento"] = codificador.fit_transform(tabela["comportamento_pagamento"])
#
# NameError: name 'tabela' is not defined

# %%
#A Coluna que eu quero prever é Y
#X é a coluna que eu uso para fazer a previsão

y = tabela["score_credito"]
x = tabela.drop(columns = ["score_credito", "id_cliente"])

from sklearn.model_selection import train_test_split

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y)

# %%
#Criar a IA
#Modelo de arvore de decisão -> RandomForest
# KNN -> Vizinho Proximos -> Kneighbors

from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

#Criar a inteligencia Artificial
modelo_arvoredecisao = RandomForestClassifier()
modelo_knn = KNeighborsClassifier()

modelo_arvoredecisao.fit(x_treino, y_treino)
modelo_knn.fit(x_treino, y_treino)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score

previsao_arvoredecisao = modelo_arvoredecisao.predict(x_teste)
previsao_knn = modelo_knn.predict(x_teste)

print(accuracy_score(y_teste, previsao_arvoredecisao))
print(accuracy_score(y_teste, previsao_knn))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cc080c84846a> in <cell line: 3>()
#       1 from sklearn.metrics import accuracy_score
#       2
# ----> 3 previsao_arvoredecisao = modelo_arvoredecisao.predict(x_teste)
#       4 previsao_knn = modelo_knn.predict(x_teste)
#       5
#
# NameError: name 'modelo_arvoredecisao' is not defined

# %%
#Fazer novas previsões
novos_clientes = pd.read_csv("novos_clientes.csv")
display(novos_clientes)

#Codificar os novos clientes
novos_clientes["profissao"] = codificador.fit_transform(novos_clientes["profissao"])
novos_clientes["mix_credito"] = codificador.fit_transform(novos_clientes["mix_credito"])
novos_clientes["comportamento_pagamento"] = codificador.fit_transform(novos_clientes["comportamento_pagamento"])

#fazer as previsões

previsoes = modelo_arvoredecisao.predict(novos_clientes)
print(previsoes)
# Out:
#    mes  idade   profissao  salario_anual  num_contas  num_cartoes  \
# 0    1   31.0  empresario      19300.340         6.0          7.0
# 1    4   32.0    advogado      12600.445         5.0          5.0
# 2    2   48.0  empresario      20787.690         8.0          6.0
#
#    juros_emprestimo  num_emprestimos  dias_atraso  num_pagamentos_atrasados  \
# 0              17.0              5.0         52.0                      19.0
# 1              10.0              3.0         25.0                      18.0
# 2              14.0              7.0         24.0                      14.0
#
#    ...  taxa_uso_credito idade_historico_credito  investimento_mensal  \
# 0  ...         29.934186                   218.0             44.50951
# 1  ...         28.819407                    12.0              0.00000
# 2  ...         34.235853                   215.0              0.00000
#
#        comportamento_pagamento  saldo_final_mes  emprestimo_carro  \
# ...
